# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 import pandas as pd
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
import numpy.random as npr
l=npr.random(10)
file_name="simple_data.txt"
with open (file_name,"w") as file:
    for i in l:
        file.write(str(i)+",")

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
m=npr.random(25).reshape(5,5)
file_name="data.txt"
with open(file_name, "w") as file:
    for i in range(0,5):
        for j in range (0,5):
            if j!=4:
                file.write(str(m[i,j])+",")
            else:
                file.write(str(m[i,j]))
        file.write("\n")

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
import numpy as np
import csv
file_name="/home/turino/UNI/I/LCP/LaboratoryOfComputationalPhysics_Y8/data.txt"
m=np.loadtxt(file_name, delimiter=",")
file_name="data_ex5.csv"
with open(file_name,"w") as file:
    for row in m:
        file.write(",".join(str(x) for x in row) + "\n")

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
file_name="/home/turino/UNI/I/LCP/LaboratoryOfComputationalPhysics_Y8/credit_card.dat"
cards=[]
with open(file_name,"r") as file:
    lines=file.read().splitlines()
for l in lines:
    l=l[:-4]
    chunks=[l[i:i+6] for i in range(0, len(l),6)]
    card ="".join(str(int(bits,2)) for bits in chunks)
    cards.append(card)
  
print(cards)
# Out:
# ['55545256325354555132515555533250505549', '51505355325650525532515153523250505454', '50555050324848484932524849493254545350', '48545449325148545132515552503251495348', '48525150324954485632495254503252555250', '53565055325048505532565556533255514851', '53555552325653505632504856553249494955', '56495248324950494832545153503250565253', '53555452324949515132555148493255494848', '54525354324955515532524950543254555054', '49505056325654514932555156503248484848', '55485349324849544832535155523251495454', '48544956325153565532495451483254515554', '49535253325352535232555252523253545154', '54555153325149495432515048503254565152', '55505655325348494932495352553256524951', '55485151325054485532515150563252504848', '50535456325350525232495655523253485052', '49545652325050535132555355483255494956', '48545550325053555432485355533254545149', '54515150325651535132565556553249515248', '49564951325151544932494955533252504949', '50525555325452534832565652483250515456', '535349503251534853325053545132
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json
file_name="/home/turino/UNI/I/LCP/LaboratoryOfComputationalPhysics_Y8/user_data.json"
data=json.load(open(file_name))
o_file="creditcard.csv" 
with open(o_file,"w") as file:
    for pp in data:
        if pp['CreditCardType']=='American Express':
            file.write(",".join(str(v) for v in pp.values()) + "\n")

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
import pandas as pd
url="https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1"
df=pd.read_csv(url)
df["class"].hist()
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
url="https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1"
df=pd.read_csv(url)
df[["features_1","features_2"]].plot()
df[["features_1","features_3"]].plot()
df[["features_2","features_3"]].plot()
# Out:
# <Axes: >

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
url="https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1"
df=pd.read_csv(url)
df.to_json("mushrooms.json",orient="records", indent=2)
