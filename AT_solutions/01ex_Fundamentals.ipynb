# %% [markdown]
# 0\. Implement a function (whatever you want) and save it to a file (e.g. `function.py`). Import that file and use that function in this notebook.

# %%
from function import function

f=function(3)
f
# Out:
# 30

# %% [markdown]
# 1\. Write the following as a list comprehension

# %%
# 1
ans = []
for i in range(3):
    for j in range(4):
        ans.append((i, j))
print (ans)

lis=[ (i,j) for i in range(3) for j in range(4)]
print(lis)
# 2
ans = map(lambda x: x*x, filter(lambda x: x%2 == 0, range(5)))
print (list(ans))

lis=[ x*x for x in range (5) if x%2==0]
print(lis)
# Out:
# [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3)]
# [(0, 0), (0, 1), (0, 2), (0, 3), (1, 0), (1, 1), (1, 2), (1, 3), (2, 0), (2, 1), (2, 2), (2, 3)]
# [0, 4, 16]
# [0, 4, 16]

# %% [markdown]
# 2\. Convert the following function into a pure function with no global variables or side effects

# %%
x = 5
def f(alis):
    for i in range(x):
         alis.append(i)
    return alis

alist = [1,2,3]
ans = f(alist.copy())
print (ans)
print (alist) # alist has been changed!
# Out:
# [1, 2, 3, 0, 1, 2, 3, 4]
# [1, 2, 3]

# %% [markdown]
# 3\. Write a `decorator` hello that makes every wrapped function print “Hello!”, i.e. something like:
#
# ```python
# @hello
# def square(x):
#     return x*x
# ```

# %%
def hello(func):
    def wrapper(*args, **kwargs):
        print("Hello")
        return func(*args, **kwargs)
    return wrapper 

@hello
def summ(a,b):
    return a+b

a,b=4,5
result=summ(a,b)
print(result)
# Out:
# Hello
# 9

# %% [markdown]
# 4\. Write the factorial function so that it a) does and b) does not use recursion.

# %%
x=input()
fact=1
count=int(x)
for i in range(1,count+1):
        fact*=i

print(fact)

y=int(input())
fact_2=1
def func(x):
    if x==1:
        return 1
    else:
        return x*func(x-1)

fact_2=func(y)
print(fact_2)
# Out:
#  4
# 24
#  4
# 24

# %% [markdown]
# 5\. Use HOFs (zip in particular) to compute the weight of a circle, a disk and a sphere, assuming different radii and different densities:
#
# ```python
# densities = {"Al":[0.5,1,2],"Fe":[3,4,5],"Pb": [15,20,30]}
# radii = [1,2,3]
# ```
#
# where the entries of the dictionary's values are the linear, superficial and volumetric densities of the materials respectively.
#
# In particular define a list of three lambda functions using a comprehension that computes the circumference, the area and the volume for a given radius.

# %%
import math
densities={"Al":[0.5,1,2],"Fe":[3,4,5],"Pb": [15,20,30]}
radii = [1,2,3]

lin = lambda x,y : 2*math.pi*x*y
quad = lambda x,y : 4*math.pi*x*y*y
cubic = lambda x,y : 4*math.pi*x*y*y*y/3

for materials, densities_list in densities.items():
    for x,y in zip(densities_list,radii):
        print("Material",materials,"with radius",y)
        print("Densità lineare", lin(x,y))
        print("Densità superficiale", quad(x,y))
        print("Densità sferica", cubic(x,y))
# Out:
# Material Al with radius 1
# Densità lineare 3.141592653589793
# Densità superficiale 6.283185307179586
# Densità sferica 2.0943951023931953
# Material Al with radius 2
# Densità lineare 12.566370614359172
# Densità superficiale 50.26548245743669
# Densità sferica 33.510321638291124
# Material Al with radius 3
# Densità lineare 37.69911184307752
# Densità superficiale 226.1946710584651
# Densità sferica 226.1946710584651
# Material Fe with radius 1
# Densità lineare 18.84955592153876
# Densità superficiale 37.69911184307752
# Densità sferica 12.566370614359172
# Material Fe with radius 2
# Densità lineare 50.26548245743669
# Densità superficiale 201.06192982974676
# Densità sferica 134.0412865531645
# Material Fe with radius 3
# Densità lineare 94.24777960769379
# Densità superficiale 565.4866776461627
# Densità sferica 565.4866776461627
# Material Pb with radius 1
# Densità lineare 94.24777960769379
# Densità superficiale 188.49555921538757
# Densità sferica 62.831853071795855
# ...

# %% [markdown]
# 6\. Edit the class definition to add an instance attribute of is_hungry = True to the Dog class. Then add a method called eat() which changes the value of is_hungry to False when called. Figure out the best way to feed each dog and then output “My dogs are hungry.” if all are hungry or “My dogs are not hungry.” if all are not hungry. The final output should look like this:
#
# `I have 3 dogs.
# Tom is 6.
# Fletcher is 7.
# Larry is 9.
# And they're all mammals, of course.
# My dogs are not hungry.
# `
#
# ```python
# # Parent class
# class Dog:
#
#     # Class attribute
#     species = 'mammal'
#
#     # Initializer / Instance attributes
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     # instance method
#     def description(self):
#         return "{} is {} years old".format(self.name, self.age)
#
#     # instance method
#     def speak(self, sound):
#         return "{} says {}".format(self.name, sound)
#
# # Child class (inherits from Dog class)
# class RussellTerrier(Dog):
#     def run(self, speed):
#         return "{} runs {}".format(self.name, speed)
#
# # Child class (inherits from Dog class)
# class Bulldog(Dog):
#     def run(self, speed):
#         return "{} runs {}".format(self.name, speed)
# ```
