# %% [markdown]
# ## Pandas analysis
#
# This exercise consists in analyzing a dataset containg timing information from a series of Time-to-Digital-Converters (TDC) implemented in a couple of FPGAs. Each measurement (i.e. each row of the input file) consists of a flag that specifies the type of message ('HEAD', which in this case is always 1), two addresses of the TDC providing the signal ('FPGA' and 'TDC_CHANNEL'), and the timing information ('ORBIT_CNT', 'BX_COUNTER', and 'TDC_MEAS'). Each TDC count corresponds to 25/30 ns, whereas a unit of BX_COUNTER corresponds to 25 ns, and the ORBIT_CNT is increased every 'x' BX_COUNTER. This allows to store the time in a similar way to hours, minutes and seconds.

# %%
# If you didn't download it yet, please get the relevant file now!
# !wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/
# Out:
# --2026-01-07 16:20:46--  https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.69.18, 2620:100:6025:18::a27d:4512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.69.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/pkkpoxlm7beasryexpdf8/data_000637.txt?rlkey=rkm2em1v57hewglzelmin21c9 [following]
# --2026-01-07 16:20:46--  https://www.dropbox.com/scl/fi/pkkpoxlm7beasryexpdf8/data_000637.txt?rlkey=rkm2em1v57hewglzelmin21c9
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucb8ecdcd7b7dd17563ca8085362.dl.dropboxusercontent.com/cd/0/inline/C4jjk6pdBDm_FQmF4n05srcZKO4wffkdsLLZFNHv2i4DT8F6DSbecPSmZXbjNfwcPR_zw_UHJmtp4NQALdZqYcOCscMCjyoArp7WUOOnbQ6udrBvN1QaNEiTo3bUZsFDALc/file# [following]
# ...

# %% [markdown]
# 1\. Create a Pandas DataFrame reading N rows of the 'data_000637.txt' dataset. Choose N to be smaller than or equal to the maximum number of rows and larger that 10k.
#
# 2\. Find out the number of BX in a ORBIT (the value 'x').
#
# 3\. Find out how much the data taking lasted. You can either make an estimate based on the fraction of the measurements (rows) you read, or perform this check precisely by reading out the whole dataset.
#
# 4\. Create a new column with the absolute time in ns (as a combination of the other three columns with timing information).
#
# 5\. Replace the values (all 1) of the HEAD column randomly with 0 or 1.
#
# 6\. Create a new DataFrame that contains only the rows with HEAD=1.
#
# 7\. Make two occupancy plots (one for each FPGA), i.e. plot the number of counts per TDC channel
#
# 8\. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)
#
# 9\. Count the number of unique orbits. Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139

# %%
import pandas as pd
import numpy as np
import numpy.random as npr
file_name="/home/turino/UNI/I/LCP/LaboratoryOfComputationalPhysics_Y8/data/data_000637.txt"
df=pd.read_csv(file_name)
rows=len(df)
N=10000
while ( N>rows or N<1e4):
       N=int(input())
#for a random estrapolation
random_indices = np.random.randint(0, rows, size=N)
df_0 = df.iloc[random_indices]
#for the first N values
df_0=df[0:N:]
# here i put N=rows for point 2
N=rows
bx_span = df.groupby('ORBIT_CNT')['BX_COUNTER'].agg(lambda x: x.max() - x.min())
x=max(bx_span)
x
# Out:
# 3563

# %%
## point 3 
time_i=int(df['ORBIT_CNT'].iloc[0]*x + df['BX_COUNTER'].iloc[0]*25 + df['BX_COUNTER'].iloc[0]*25/30)
time_f=int(df['ORBIT_CNT'].iloc[-1]*x + df['BX_COUNTER'].iloc[-1]*25 + df['BX_COUNTER'].iloc[-1]*25/30)
delta_t=time_f-time_i
delta_t*=1e-9
print("TIME:",delta_t)
# Out:
# TIME: 0.039165609000000004

# %%
## point 4
abs_time=np.zeros(rows)
for i in range(0,rows):
        abs_time[i]=df['ORBIT_CNT'].iloc[i] * x * 25+ df['BX_COUNTER'].iloc[i] * 25 + df['TDC_MEAS'].iloc[i] * (25 / 30)
df['abs_time']=abs_time
df
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
#              abs_time
# 0        3.446490e+14
# 1        3.446490e+14
# 2        3.446490e+14
# 3        3.446490e+14
# 4        3.446490e+14
# ...

# %%
## point 5
new_head=np.zeros(rows)
for i in range(0,rows):
    x=np.random.randint(0,2)
    new_head[i]=x

df['HEAD']=pd.Series(new_head,index=df.index)
df
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0         1.0     0          123  3869200167        2374        26
# 1         1.0     0          124  3869200167        2374        27
# 2         0.0     0           63  3869200167        2553        28
# 3         0.0     0           64  3869200167        2558        19
# 4         1.0     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715   0.0     0           62  3869211171         762        14
# 1310716   0.0     1            4  3869211171         763        11
# 1310717   1.0     0           64  3869211171         764         0
# 1310718   0.0     0          139  3869211171         769         0
# 1310719   0.0     0           61  3869211171         762        18
#
#              abs_time
# 0        3.446490e+14
# 1        3.446490e+14
# 2        3.446490e+14
# 3        3.446490e+14
# 4        3.446490e+14
# ...

# %%
#point 6
df_0=df[df['HEAD']==1]
df_0
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0         1.0     0          123  3869200167        2374        26
# 1         1.0     0          124  3869200167        2374        27
# 4         1.0     0           64  3869200167        2760        25
# 6         1.0     0           61  3869200167        2772        14
# 7         1.0     0          139  3869200167        2776         0
# ...       ...   ...          ...         ...         ...       ...
# 1310707   1.0     0           57  3869211171         137        29
# 1310710   1.0     1           36  3869211171         427        13
# 1310711   1.0     1           39  3869211171         430         0
# 1310713   1.0     0           64  3869211171         758        18
# 1310717   1.0     0           64  3869211171         764         0
#
#              abs_time
# 0        3.446490e+14
# 1        3.446490e+14
# 4        3.446490e+14
# 6        3.446490e+14
# 7        3.446490e+14
# ...

# %%
#point 7
import matplotlib.pyplot as plt
FPGA_0=df[df['FPGA']==0]
FPGA_1=df[df['FPGA']==1]

count_0=FPGA_0.groupby('TDC_CHANNEL').size().reset_index(name='count')
plt.plot(count_0['TDC_CHANNEL'],count_0['count'])
count_1=FPGA_1.groupby('TDC_CHANNEL').size().reset_index(name='count')
plt.plot(count_1['TDC_CHANNEL'],count_1['count'])

# %%
#point 8
counts=df.groupby('TDC_CHANNEL').size()
top3 = counts.nlargest(3).reset_index()
top3.columns = ['TDC_CHANNEL', 'count']
top3
# Out:
#    TDC_CHANNEL   count
# 0          139  108059
# 1           64   66020
# 2           63   64642

# %%
#point 9 
orbit=df.groupby('TDC_CHANNEL')['ORBIT_CNT'].agg(lambda x : x.max()-x.min()).reset_index(name='diff_orbit')
orbit_c139=orbit[orbit['TDC_CHANNEL']==139]
orbit_c139
# Out:
#      TDC_CHANNEL  diff_orbit
# 132          139       11004
