# %% [markdown]
# 1\. Write a function that converts number representation, bin<->dec<->hex. (Clearly using the corresponding python built-in functions is not fair..)

# %%
def dextobin(x) :
    if x==0:
        print([0])
        return
    a=[]
    if x>0:
        sign=0
    else:
        sign=1
        
    x=abs(x)
    while(x>0):
      a.append(x%2)
      x//=2
    a.append(sign)
    a.reverse()
    
    print(a)

n=24
dextobin(n)
def dextohex(x) :
    if x==0:
        print([0])
        return
    a=[]
    if x>0:
        sign=0
    else:
        sign=1
        
    x=abs(x)
    hex_digits="0123456789ABCDEF"
    while(x>0):
      a.append(hex_digits[x%16])
      x//=16
    a.append(sign)
    a.reverse()
    
    print(a)

n=-15
dextohex(n)
# Out:
# [0, 1, 1, 0, 0, 0]
# [1, 'F']

# %% [markdown]
# 2\. Write a function that converts a 32 bit word into a single precision floating point (i.e. interprets the various bits as sign, mantissa and exponent)

# %%
def floating(x):
    
    f=x[9:]
    e=x[1:9]
    s=x[0]

    mantissa=1
    for i in range(0,23):
        mantissa+=int(f[i],2)*pow(2,-i-1)
    
    word_f=pow(-1,int(s,2))*mantissa*pow(2,int(e,2)-127)
    
    print(word_f)
    
#word=input("Insert word in bit")
floating("01000000000110000000000000000000")
# Out:
# 2.375

# %% [markdown]
# 3\. Write a program to determine the underflow and overflow limits (within a factor of 2) for python on your computer.
#
# **Tips**: define two variables inizialized to 1 and halve/double them enough time to exceed the under/over-flow limits

# %%
x,y=1.0,1.0
while x!=float('inf'):
    prev=x
    x*=2

print("Numero overflow:",prev)
while y!=float(0):
    prev=y
    y/=2
print("Numero underflow:",prev)
# Out:
# Numero overflow: 8.98846567431158e+307
# Numero underflow: 5e-324

# %% [markdown]
# 4\. Write a program to determine the machine precision
#
# **Tips**: define a new variable by adding a smaller and smaller value (proceeding similarly to prob. 2) to an original variable and check the point where the two are the same

# %%
x=1.0
y=1.0
var=1.0
while x!=(y+var):
    prev=var
    var/=2

print("Machine precision:",prev)
# Out:
# Machine precision: 2.220446049250313e-16

# %% [markdown]
# 5\. Write a function that takes in input three parameters $a$, $b$ and $c$ and prints out the two solutions to the quadratic equation $ax^2+bx+c=0$ using the standard formula:
# $$
# x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}
# $$
#
# (a) use the program to compute the solution for $a=0.001$, $b=1000$ and $c=0.001$
#
# (b) re-express the standard solution formula by multiplying top and bottom by $-b\mp\sqrt{b^2-4ac}$ and again find the solution for $a=0.001$, $b=1000$ and $c=0.001$. How does it compare with what previously obtained? Why?
#
# (c) write a function that compute the roots of a quadratic equation accurately in all cases

# %%
def sq_root(a,b,c):
    x_1=(-b+pow(b**2-4*a*c,1/2))/(2*a)
    x_2=(-b-pow(b**2-4*a*c,1/2))/(2*a)
    return(x_1,x_2)

a,b,c=1,+1000,0.001
x1,x2=sq_root(a,b,c)
print(x1,x2)

def sq_root2(a,b,c):
    x_1=(4*a*c)/(2*a*(-b-pow(b**2-4*a*c,1/2)))
    x_2=(4*a*c)/(2*a)*(-b+pow(b**2-4*a*c,1/2))
    return(x_1,x_2)
    
x1,x2=sq_root2(a,b,c)
print(x1,x2)    

def sq_root_acc(a,b,c):
    if b>=0 :
        x_1=(4*a*c)/(2*a*(-b-pow(b**2-4*a*c,1/2)))
        x_2=(-b-pow(b**2-4*a*c,1/2))/(2*a)
    else:
        x_1=(-b+pow(b**2-4*a*c,1/2))/(2*a)
        x_2=(4*a*c)/(2*a)*(-b+pow(b**2-4*a*c,1/2))
    return(x_1,x_2)

x1,x2=sq_root_acc(a,b,c)
print(x1,x2)
# Out:
# -9.999999974752427e-07 -999.999999
# -1.000000001e-06 -3.999999989900971e-09
# -1.000000001e-06 -999.999999

# %% [markdown]
# 6\. Write a program that implements the function $f(x)=x(x−1)$
#
# (a) Calculate the derivative of the function at the point $x = 1$ using the derivative definition:
#
# $$
# \frac{{\rm d}f}{{\rm d}x} = \lim_{\delta\to0} \frac{f(x+\delta)-f(x)}{\delta}
# $$
#
# with $\delta = 10^{−2}$. Calculate the true value of the same derivative analytically and compare with the answer your program gives. The two will not agree perfectly. Why not?
#
# (b) Repeat the calculation for $\delta = 10^{−4}, 10^{−6}, 10^{−8}, 10^{−10}, 10^{−12}$ and $10^{−14}$. How does the accuracy scales with $\delta$?

# %%
delta=1e-2
der=((1+delta)*(delta))/(delta)

print(der)
for i in range(1,7):
    delta/=1e2
    der=((1+delta)*(delta))/(delta)
    print("derivate with delta %e : %.23f"%(delta,der))
# Out:
# 1.01
# derivate with delta 1.000000e-04 : 1.00009999999999998898659
# derivate with delta 1.000000e-06 : 1.00000099999999991773336
# derivate with delta 1.000000e-08 : 1.00000000999999993922529
# derivate with delta 1.000000e-10 : 1.00000000010000000827404
# derivate with delta 1.000000e-12 : 1.00000000000100008890058
# derivate with delta 1.000000e-14 : 1.00000000000000999200722

# %% [markdown]
# 7\. Consider the integral of the semicircle of radius 1:
# $$
# I=\int_{-1}^{1} \sqrt{(1-x^2)} {\rm d}x
# $$
# which it's known to be $I=\frac{\pi}{2}=1.57079632679...$.
# Alternatively we can use the Riemann definition of the integral:
# $$
# I=\lim_{N\to\infty} \sum_{k=1}^{N} h y_k
# $$
#
# with $h=2/N$ the width of each of the $N$ slices the domain is divided into and where
# $y_k$ is the value of the function at the $k-$th slice.
#
# (a) Write a programe to compute the integral with $N=100$. How does the result compares to the true value?
#
# (b) How much can $N$ be increased if the computation needs to be run in less than a second? What is the gain in running it for 1 minute?

# %%
# %%time
import math as m
N=100
I=0.0
for i in range(N):
    I+=2/N * (m.sqrt(1-(-1+i/N)**2))

print(I) 

for i in range (1,9):
    N=pow(10,i)
    I=0
    for i in range(N):
        I+=2/N * (m.sqrt(1-(-1+i/N)**2))
        
    print("The integral for N=%e results:"%(N),I)
#per N=1e7 impiega circa 2.64 s
print("The true value is:", m.pi/2)
diff=m.pi/2 - I
print("The difference between the approximation and the real value, after 1 minute of computing, is:",diff)
# Out:
# 1.5602085158895227
# The integral for N=1.000000e+01 results: 1.4522591631241593
# The integral for N=1.000000e+02 results: 1.5602085158895227
# The integral for N=1.000000e+03 results: 1.5697777334555134
# The integral for N=1.000000e+04 results: 1.570695738805664
# The integral for N=1.000000e+05 results: 1.5707863082009823
# The integral for N=1.000000e+06 results: 1.570795326206901
# The integral for N=1.000000e+07 results: 1.5707962267762947
# The integral for N=1.000000e+08 results: 1.5707963167941232
# The true value is: 1.5707963267948966
# The difference between the approximation and the real value, after 1 minute of computing, is: 1.0000773320584244e-08
# CPU times: user 24.9 s, sys: 1.51 ms, total: 24.9 s
# Wall time: 24.9 s
